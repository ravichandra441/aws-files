# %%
import boto3

# %%
session = boto3.Session(aws_access_key_id="AKIAX4UHL5Z6FLCF2CFP",aws_secret_access_key="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")

# %%
dev_s3_clint = session.client("s3")

# %%
dev_s3_clint.list_buckets()
# Out:
# {'ResponseMetadata': {'RequestId': '55ADC2632C02F18D',
#   'HostId': 'ZZuxpLqaLcTnvMb96CbYjpg9VzyWeQDiJQWIbYRG7glqcFYZrrloZeFJz4yXqBuVMhF/AT1cwRM=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'ZZuxpLqaLcTnvMb96CbYjpg9VzyWeQDiJQWIbYRG7glqcFYZrrloZeFJz4yXqBuVMhF/AT1cwRM=',
#    'x-amz-request-id': '55ADC2632C02F18D',
#    'date': 'Sun, 07 Feb 2021 13:51:15 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'wafer-fault-detection-bucket',
#    'CreationDate': datetime.datetime(2021, 2, 7, 13, 46, 46, tzinfo=tzutc())}],
#  'Owner': {'DisplayName': 'chandraravi662',
#   'ID': '51451dd5450a6e4e26adc146c9567d380789ff5c3d9119a11851e641020cd2d0'}}

# %%
s = dev_s3_clint.list_objects(Bucket ='wafer-fault-detection-bucket' )

# %%
s["Contents"]
import boto3
import pandas as pd

s3 = boto3.client('s3')
obj = s3.get_object(Bucket='bucket', Key='key')
df = pd.read_csv(obj['Body'])
# Out:
# [{'Key': 'Wafer_07012020_223345.csv',
#   'LastModified': datetime.datetime(2021, 2, 7, 13, 53, 43, tzinfo=tzutc()),
#   'ETag': '"dbfb370df51c35306514b009f1f781e3"',
#   'Size': 348403,
#   'StorageClass': 'STANDARD',
#   'Owner': {'ID': '51451dd5450a6e4e26adc146c9567d380789ff5c3d9119a11851e641020cd2d0'}}]

# %%
obj = dev_s3_clint.get_object(Bucket = 'wafer-fault-detection-bucket',Key ='Wafer_07012020_223345.csv')

# %%
success = pd.read_csv(obj["Body"])

# %%
success
# Out:
#     Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0   Wafer-1200   2979.32   2493.34  2226.4667  1591.2235    2.1717       100
# 1   Wafer-1201   3045.98   2544.85  2253.3444  1873.8678    1.1691       100
# 2   Wafer-1202   3151.98   2563.75  2175.2556  1022.1660    1.2833       100
# 3   Wafer-1203   3071.18   2489.86  2195.3000  1151.8233    0.9220       100
# 4   Wafer-1204   2958.46   2523.78  2171.8556  1156.6018    1.4025       100
# ..         ...       ...       ...        ...        ...       ...       ...
# 95  Wafer-1295   3224.10   2410.53  2208.9778  1285.2144    2.4210       100
# 96  Wafer-1296   3193.53   2587.86  2162.1333   998.9095    0.8826       100
# 97  Wafer-1297   3033.52   2461.08  2203.1667  1312.9527    0.9448       100
# 98  Wafer-1298   3188.42   2565.93  2208.9000   934.7558    1.9469       100
# 99  Wafer-1299   3177.96   2369.84  2162.1333   998.9095    0.8826       100
#
# ...
